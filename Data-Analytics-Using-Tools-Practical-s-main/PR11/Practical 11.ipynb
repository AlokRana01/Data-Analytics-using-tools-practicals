# %%
import pandas as pd

df = pd.read_csv('employee_data.csv')

print(df.head())
print(df.info())
print(df.describe(include='all'))
# Out:
#    EmployeeID   Name   Age Department  Salary   Bonus  Gender
# 0           1   John  25.0         HR   50000  5000.0    Male
# 1           2  Alice  30.0         IT   60000  6000.0  Female
# 2           3    Bob   NaN         hr   55000  5500.0    Male
# 3           4  Carol  28.0    IT Dept   62000     NaN  Female
# 4           5  David  35.0    Finance   70000  7000.0    Male
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   EmployeeID  11 non-null     int64
#  1   Name        11 non-null     object
#  2   Age         10 non-null     float64
#  3   Department  11 non-null     object
#  4   Salary      11 non-null     int64
#  5   Bonus       10 non-null     float64
#  6   Gender      11 non-null     object
# dtypes: float64(2), int64(2), object(3)
# memory usage: 748.0+ bytes
# None
#         EmployeeID  Name        Age Department          Salary        Bonus  \
# count    11.000000    11  10.000000         11       11.000000    10.000000
# unique         NaN    10        NaN          6             NaN          NaN
# top            NaN  John        NaN         HR             NaN          NaN
# freq           NaN     2        NaN          4             NaN          NaN
# mean      6.000000   NaN  29.600000        NaN   146909.090909  6440.000000
# std       3.316625   NaN   4.765618        NaN   283088.839252  1325.141502
# min       1.000000   NaN  25.000000        NaN    50000.000000  5000.000000
# 25%       3.500000   NaN  26.250000        NaN    56500.000000  5575.000000
# 50%       6.000000   NaN  28.500000        NaN    60000.000000  5950.000000
# 75%       8.500000   NaN  30.750000        NaN    71000.000000  7150.000000
# max      11.000000   NaN  40.000000        NaN  1000000.000000  9000.000000
#
#        Gender
# count      11
# unique      2
# top      Male
# freq        6
# mean      NaN
# std       NaN
# min       NaN
# 25%       NaN
# 50%       NaN
# 75%       NaN
# max       NaN

# %%
print(df.isnull().sum())

missing_percentage = df.isnull().mean() * 100
print(missing_percentage)
# Out:
# EmployeeID    0
# Name          0
# Age           1
# Department    0
# Salary        0
# Bonus         1
# Gender        0
# dtype: int64
# EmployeeID    0.000000
# Name          0.000000
# Age           9.090909
# Department    0.000000
# Salary        0.000000
# Bonus         9.090909
# Gender        0.000000
# dtype: float64

# %%
df = df.dropna()

# %%
df['Salary'] = df['Salary'].fillna(df['Salary'].mean())

# %%
df['Department'] = df['Department'].fillna(df['Department'].mode()[0])

# %%
Q1 = df['Salary'].quantile(0.25)
Q3 = df['Salary'].quantile(0.75)
IQR = Q3 - Q1

df = df[~((df['Salary'] < (Q1 - 1.5 * IQR)) | (df['Salary'] > (Q3 + 1.5 * IQR)))]

# %%
print(df.duplicated().sum())
df = df.drop_duplicates()
# Out:
# 0

# %%
df['Department'] = df['Department'].str.lower().str.strip()

df['Department'] = df['Department'].replace({
    'hr': 'human resources',
    'it dept': 'it'
})

# %%
df.to_csv('cleaned_data.csv', index=False)
